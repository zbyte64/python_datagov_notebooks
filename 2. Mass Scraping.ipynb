# %% [markdown]
# # Downloading Data in Bulk

# %% [markdown]
# There are allot of things that can go wrong when downloading in bulk. Not only can requests time out but allot of entries are incorrect. Sometimes the API says it gave you a CSV link when it really gave you xml. Or maybe the API didn't say how big the file is and it turns out to be a 2`GB` census file. Or maybe it is a CSV file but it is zipped up.

# %% [markdown]
# Below is code to use `asyncio` to peek at our downloads and abort any files that are not real `CSVs`. This code will also allow for downloading in parrallel and will cache the data into subfolders to avoid redownloading anything we already have.

# %%
import aiohttp, asyncio, pandas, os, requests, collections, urllib, shutil
from time import sleep

host_semaphores = collections.defaultdict(asyncio.Semaphore) #only 1 request per host name

async def peek_if_csv_and_write(url, folder, max_readline=1024*12, max_size=1024*1024*10): #max_size = 10MB
    if os.path.exists(folder):
        #print(folder, "Already exists")
        return True
    else:
        os.mkdir(folder)
    host = urllib.parse.urlparse(url).netloc
    await host_semaphores[host].acquire()
    print(folder, "Downloading:", url)
    async with aiohttp.ClientSession() as session:
        try:
            resp_with_timer = await asyncio.wait_for(session.get(url), 5.0)
            async with resp_with_timer as resp:
                if resp.status != 200:
                    print(folder, "got non 200 response:", resp.status)
                    return False
                #content-disposition: attachment; filename=foo.pdf
                #content-length
                if 'CONTENT-DISPOSITION' not in resp.headers:
                    print(folder, "no content disposition found")
                    return False
                dst = resp.headers['CONTENT-DISPOSITION'].split('; filename=')[-1]
                dst = os.path.join(folder, dst)
                print(folder, "Destination:", dst)
                if os.path.exists(dst):
                    return dst
                size = int(resp.headers.get('CONTENT-LENGTH', 0))
                #if size is 0:
                #    print("no size reported")
                #    #return False
                if size > max_size:
                    print(folder, "too big of a file")
                    return False
                if dst.endswith('.csv'):
                    read_bytes = await resp.content.read(max_readline)
                    if b'\n' not in read_bytes:
                        print(folder, "no new line found, probably not a csv")
                        return False
                    output = open(dst, 'wb')
                    output.write(read_bytes)
                    while True:
                        chunk = await resp.content.read()
                        if chunk:
                            output.write(chunk)
                        else:
                            break
                    output.close()
                    try:
                        pandas.read_csv(dst, nrows=3)
                    except Exception as error:
                        print(folder, "Not a CSV:", error)
                        return False
                elif dst.endswith('.zip'):
                    print(folder, "zipfile found, skipping")
                    return False
                    if size is 0:
                        #ouch, dangerous
                        return False
                    #TODO figure out folder structure to handle this
                    bytes_so_far = 0
                    output = open(dst, 'wb')
                    while True:
                        if bytes_so_far > max_size:
                            return False #TOO big of a zip file and they didn't tell us how big!
                        chunk = await resp.content.read()
                        if chunk:
                            bytes_so_far += len(chunk)
                            output.write(chunk)
                        else:
                            break
                    output.close()
                    #TODO unzip
                else:
                    print(folder, "Unrecognized filetype:", dst)
                    return False
                return dst
        except asyncio.TimeoutError:
            print(folder, "timed out")
            shutil.rmtree(folder, True)
            return False
        except (aiohttp.errors.ServerDisconnectedError, ConnectionResetError) as error:
            print(folder, "angry server", error)
            shutil.rmtree(folder, True)
            return False
        finally:
            host_semaphores[host].release()

loop = asyncio.new_event_loop()
asyncio.set_event_loop(loop)

#download all the csvs (or the first 10 pages...)
for i in range(10): #int(13460/10) + 1):
    offset = i * 10
    raw_response = requests.get('http://catalog.data.gov/api/search/dataset', params={'all_fields':1, 'res_format':'CSV', 'offset': offset})
    try:
        response = raw_response.json()
    except:
        print("ERROR", ras_response.status)
        sleep(5)
        continue
    results = response['results']
    urls = [(dataset['res_url'][dataset['res_format'].index('CSV')], dataset['id']) for dataset in results]
    futures = [asyncio.ensure_future(peek_if_csv_and_write(url, did)) for url, did in urls]
    loop.run_until_complete(asyncio.gather(*futures))

loop.close()
# Out:
# 9bbedbcc-06b9-4762-a214-feed76df94d8 Downloading: https://data.illinois.gov/api/views/rry2-usaj/rows.csv?accessType=DOWNLOAD
# 9bbedbcc-06b9-4762-a214-feed76df94d8 Destination: 9bbedbcc-06b9-4762-a214-feed76df94d8/05to09_Iquery_Hep_Cchronic_Data.csv
# 4923637b-0eca-4820-ad7b-ef8678fd6777 Downloading: https://data.illinois.gov/api/views/5cng-jyjz/rows.csv?accessType=DOWNLOAD
# 4923637b-0eca-4820-ad7b-ef8678fd6777 Destination: 4923637b-0eca-4820-ad7b-ef8678fd6777/05to12_Iquery_Crypto_Data.csv
# c08f27d3-9ebc-4ef4-8303-1789f4d7676c Downloading: https://data.illinois.gov/api/views/rjxh-tv66/rows.csv?accessType=DOWNLOAD
# c08f27d3-9ebc-4ef4-8303-1789f4d7676c Destination: c08f27d3-9ebc-4ef4-8303-1789f4d7676c/05to12_Iquery_Hep_AData.csv
# fd0ddbe4-4187-4ad0-8a7b-2ab24e6ef763 Downloading: https://data.illinois.gov/api/views/pwfa-6r2g/rows.csv?accessType=DOWNLOAD
# fd0ddbe4-4187-4ad0-8a7b-2ab24e6ef763 Destination: fd0ddbe4-4187-4ad0-8a7b-2ab24e6ef763/05to12_Iquery_Hep_Bchronic_Data.csv
# 46d2b61c-7384-4a50-a859-4bbb41e6a8e6 Downloading: https://data.illinois.gov/api/views/h79e-pjdp/rows.csv?accessType=DOWNLOAD
# 46d2b61c-7384-4a50-a859-4bbb41e6a8e6 Destination: 46d2b61c-7384-4a50-a859-4bbb41e6a8e6/05to12_Iquery_Histo_Data.csv
# 1ff5eab4-01be-4e9e-b9a2-f9147742cd49 Downloading: https://data.illinois.gov/api/views/iyx8-kpar/rows.csv?accessType=DOWNLOAD
# 1ff5eab4-01be-4e9e-b9a2-f9147742cd49 Destination: 1ff5eab4-01be-4e9e-b9a2-f9147742cd49/05to12_Iquery_Leg_Data.csv
# 85b365e0-1dae-4e31-bd60-4093b53b5a21 Downloading: https://data.illinois.gov/api/views/udvf-7ip4/rows.csv?accessType=DOWNLOAD
# 85b365e0-1dae-4e31-bd60-4093b53b5a21 Destination: 85b365e0-1dae-4e31-bd60-4093b53b5a21/05to12_Iquery_List_Data.csv
# 16c5013f-fe84-45f5-a3e5-ce3301348f31 Downloading: https://data.illinois.gov/api/views/wcrd-n5pw/rows.csv?accessType=DOWNLOAD
# 16c5013f-fe84-45f5-a3e5-ce3301348f31 Destination: 16c5013f-fe84-45f5-a3e5-ce3301348f31/05to12_Iquery_Lyme_Data.csv
# 0dd8408f-64c6-4d10-813f-b1dc66e50cfd Downloading: https://data.illinois.gov/api/views/jshf-mnjc/rows.csv?accessType=DOWNLOAD
# 0dd8408f-64c6-4d10-813f-b1dc66e50cfd Destination: 0dd8408f-64c6-4d10-813f-b1dc66e50cfd/05to12_Iquery_Mumps_Data.csv
# 8a440f80-b0b1-4a1b-a4e5-1ec30ddec448 Downloading: https://data.illinois.gov/api/views/36yw-y8bn/rows.csv?accessType=DOWNLOAD
# 8a440f80-b0b1-4a1b-a4e5-1ec30ddec448 Destination: 8a440f80-b0b1-4a1b-a4e5-1ec30ddec448/05to12_Iquery_NMen_Data.csv
# 7b02f4db-489d-4554-9b25-c3b93839dbd7 Downloading: https://data.illinois.gov/api/views/a94u-w666/rows.csv?accessType=DOWNLOAD
# 227d610a-b234-4a38-a096-b6945676e606 Downloading: https://ecos.fws.gov/ServCat/DownloadFile/57893?Reference=55991
# e9de30f0-32d2-4c34-95c0-af63900dd139 Downloading: https://data.wa.gov/api/views/vsr8-3iup/rows.csv?accessType=DOWNLOAD
# 9c34da11-990b-4d32-a0b3-8d31bfddc681 Downloading: https://data.austintexas.gov/api/views/a93c-yxmv/rows.csv?accessType=DOWNLOAD
# e9de30f0-32d2-4c34-95c0-af63900dd139 Destination: e9de30f0-32d2-4c34-95c0-af63900dd139/1_--_All____By_Biennium.csv
# 7b02f4db-489d-4554-9b25-c3b93839dbd7 Destination: 7b02f4db-489d-4554-9b25-c3b93839dbd7/05to12_Iquery_Pert_Data.csv
# 2ef4a628-f2f4-483c-a5aa-50f5966c4978 Downloading: https://data.illinois.gov/api/views/y9yg-u5x4/rows.csv?accessType=DOWNLOAD
# 227d610a-b234-4a38-a096-b6945676e606 Destination: 227d610a-b234-4a38-a096-b6945676e606/"DATASHEET_1.04_and_1.06_Water_Monitoring__Quality.csv"
# 227d610a-b234-4a38-a096-b6945676e606 Unrecognized filetype: 227d610a-b234-4a38-a096-b6945676e606/"DATASHEET_1.04_and_1.06_Water_Monitoring__Quality.csv"
# b035ee96-dcf8-4fe9-abef-cd7b39918ca2 Downloading: https://ecos.fws.gov/ServCat/DownloadFile/56763?Reference=55984
# b035ee96-dcf8-4fe9-abef-cd7b39918ca2 Destination: b035ee96-dcf8-4fe9-abef-cd7b39918ca2/"FHS_1.07BBS_Survey_Stop_Coordinates.csv"
# b035ee96-dcf8-4fe9-abef-cd7b39918ca2 Unrecognized filetype: b035ee96-dcf8-4fe9-abef-cd7b39918ca2/"FHS_1.07BBS_Survey_Stop_Coordinates.csv"
# 9c34da11-990b-4d32-a0b3-8d31bfddc681 got non 200 response: 400
# 2ef4a628-f2f4-483c-a5aa-50f5966c4978 Destination: 2ef4a628-f2f4-483c-a5aa-50f5966c4978/05to12_Iquery_Salm_Data.csv
# 4897223f-9142-45f2-94d0-26ccdda353d1 Downloading: https://data.illinois.gov/api/views/7ruy-jy23/rows.csv?accessType=DOWNLOAD
# 4897223f-9142-45f2-94d0-26ccdda353d1 Destination: 4897223f-9142-45f2-94d0-26ccdda353d1/05to12_Iquery_Shig_Data.csv
# c76635cd-2a4f-43da-9d93-9118c618623a Downloading: https://data.illinois.gov/api/views/f55m-q7ae/rows.csv?accessType=DOWNLOAD
# c76635cd-2a4f-43da-9d93-9118c618623a Destination: c76635cd-2a4f-43da-9d93-9118c618623a/05to12_Iquery_STECData.csv
# 521edfd2-f78d-4111-bef0-6bac65317bf4 Downloading: https://data.illinois.gov/api/views/9pyu-97m3/rows.csv?accessType=DOWNLOAD
# 521edfd2-f78d-4111-bef0-6bac65317bf4 Destination: 521edfd2-f78d-4111-bef0-6bac65317bf4/05to12_Iquery_WNVData.csv
# 9021d7de-b829-4028-a0cd-44b6d13f8e1b Downloading: https://data.illinois.gov/api/views/9nr5-bsgm/rows.csv?accessType=DOWNLOAD
# 9021d7de-b829-4028-a0cd-44b6d13f8e1b Destination: 9021d7de-b829-4028-a0cd-44b6d13f8e1b/09to12_Iquery_Chkn_Pox_Data.csv
# a211f597-930a-4b34-a222-49b70c467300 Downloading: https://data.austintexas.gov/api/views/63qm-249s/rows.csv?accessType=DOWNLOAD
# e9c84051-f4aa-46a0-9acb-29ba405ce4c9 Downloading: https://data.ok.gov/sites/default/files/10-Year_Comparison_of_Taxpayer_Income_1.csv
# 72d45d12-7f7a-4246-b5c5-387ed5bdc211 Downloading: https://data.illinois.gov/api/views/8kzf-xyr7/rows.csv?accessType=DOWNLOAD
# 1d4f1a68-cf21-4ed3-8216-4947b09ec912 Downloading: https://www.census.gov/geo/maps-data/maps/reference-cd112.html
# 27031201-b6fd-4784-ab44-d59ca8e66e1c Downloading: http://gstore.unm.edu/apps/rgis/datasets/fb928ccf-b5c4-4f11-b949-9dd311f77f67/ag_curry_1936.derived.csv
# a211f597-930a-4b34-a222-49b70c467300 got non 200 response: 400
# 72d45d12-7f7a-4246-b5c5-387ed5bdc211 Destination: 72d45d12-7f7a-4246-b5c5-387ed5bdc211/10to12_Iquery_Flu_Data.csv
# 39cb6388-d85c-4912-af7a-56a9ada4c156 Downloading: https://data.illinois.gov/api/views/fawv-2hhj/rows.csv?accessType=DOWNLOAD
# e9c84051-f4aa-46a0-9acb-29ba405ce4c9 no content disposition found
# 1d4f1a68-cf21-4ed3-8216-4947b09ec912 no content disposition found
# 39cb6388-d85c-4912-af7a-56a9ada4c156 Destination: 39cb6388-d85c-4912-af7a-56a9ada4c156/10to12_Iquery_Hep_Cchronic_Data.csv
# 27031201-b6fd-4784-ab44-d59ca8e66e1c Destination: 27031201-b6fd-4784-ab44-d59ca8e66e1c/ag_curry_1936_csv.zip
# 27031201-b6fd-4784-ab44-d59ca8e66e1c zipfile found, skipping
# 2574c577-6903-497c-a445-696bf0e16641 Downloading: http://gstore.unm.edu/apps/rgis/datasets/29d684bc-9108-41d8-a841-e748930991c5/ag_harding_1936.derived.csv
# 2574c577-6903-497c-a445-696bf0e16641 Destination: 2574c577-6903-497c-a445-696bf0e16641/ag_harding_1936_csv.zip
# 2574c577-6903-497c-a445-696bf0e16641 zipfile found, skipping
# 97714b11-b08f-4795-b5c0-3f0230d9e706 Downloading: http://gstore.unm.edu/apps/rgis/datasets/09789fc9-4c19-4edf-8cad-a55fa44c9bfa/ag_quay_1936.derived.csv
# 97714b11-b08f-4795-b5c0-3f0230d9e706 Destination: 97714b11-b08f-4795-b5c0-3f0230d9e706/ag_quay_1936_csv.zip
# 97714b11-b08f-4795-b5c0-3f0230d9e706 zipfile found, skipping
# ec057ef9-f801-4774-88c0-affad9347755 Downloading: http://gstore.unm.edu/apps/rgis/datasets/99bcb5b4-bb33-46e3-9a43-e56d4122c8c6/ag_roosevelt_1936.derived.csv
# ec057ef9-f801-4774-88c0-affad9347755 Destination: ec057ef9-f801-4774-88c0-affad9347755/ag_roosevelt_1936_csv.zip
# ec057ef9-f801-4774-88c0-affad9347755 zipfile found, skipping
# 7d2be905-b454-4935-959b-fb8de25af4cb Downloading: http://gstore.unm.edu/apps/rgis/datasets/0d9345d7-2ae6-46f8-919a-4143090c31ae/cjb_lowerpecos_1939.derived.csv
# 7d2be905-b454-4935-959b-fb8de25af4cb Destination: 7d2be905-b454-4935-959b-fb8de25af4cb/cjb_lowerpecos_1939_csv.zip
# 7d2be905-b454-4935-959b-fb8de25af4cb zipfile found, skipping
# f84b8b16-2912-4a79-af02-22d3ef1b0c59 Downloading: http://gstore.unm.edu/apps/rgis/datasets/4ebd2132-42cd-4cca-8ed5-c77ddd3d145b/cij_curry_1939.derived.csv
# f84b8b16-2912-4a79-af02-22d3ef1b0c59 Destination: f84b8b16-2912-4a79-af02-22d3ef1b0c59/cij_curry_1939_csv.zip
# f84b8b16-2912-4a79-af02-22d3ef1b0c59 zipfile found, skipping
# a0db8e06-e340-4f39-974f-dfed33bdbe1d Downloading: http://gstore.unm.edu/apps/rgis/datasets/fc498d7e-d1c5-48fd-aa58-3d9d46e7f0bb/cii_quay_1939.derived.csv
# a0db8e06-e340-4f39-974f-dfed33bdbe1d Destination: a0db8e06-e340-4f39-974f-dfed33bdbe1d/cii_quay_1939_csv.zip
# a0db8e06-e340-4f39-974f-dfed33bdbe1d zipfile found, skipping
# 165bd78e-66f1-49f0-898f-ab64a4e41d43 Downloading: http://gstore.unm.edu/apps/rgis/datasets/cac7fe1c-561d-4909-bb2c-358112f8e16c/cik_roosevelt_1939.derived.csv
# 165bd78e-66f1-49f0-898f-ab64a4e41d43 Destination: 165bd78e-66f1-49f0-898f-ab64a4e41d43/cik_roosevelt_1939_csv.zip
# 165bd78e-66f1-49f0-898f-ab64a4e41d43 zipfile found, skipping
# dd691088-d44f-4877-90a5-4e2b5cd32d90 Downloading: http://gstore.unm.edu/apps/rgis/datasets/797d4766-bbd1-43c8-bce9-c682af53ad80/chx_upper_pecos_1939.derived.csv
# dd691088-d44f-4877-90a5-4e2b5cd32d90 Destination: dd691088-d44f-4877-90a5-4e2b5cd32d90/chx_upper_pecos_1939_csv.zip
# dd691088-d44f-4877-90a5-4e2b5cd32d90 zipfile found, skipping
# a2a339ad-7263-4d8e-a25f-b25db7ffb0a3 Downloading: http://gstore.unm.edu/apps/rgis/datasets/a0155106-d53d-4751-a814-85f2bd43662f/ctf_otero_1941.derived.csv
# a2a339ad-7263-4d8e-a25f-b25db7ffb0a3 Destination: a2a339ad-7263-4d8e-a25f-b25db7ffb0a3/ctf_otero_1941_csv.zip
# a2a339ad-7263-4d8e-a25f-b25db7ffb0a3 zipfile found, skipping
# 5cf47547-c8c0-4a67-89e6-92d035009037 Downloading: http://gstore.unm.edu/apps/rgis/datasets/abc3053a-7570-493f-ad6e-7974d02b37a6/af_1943_332.derived.csv
# 5cf47547-c8c0-4a67-89e6-92d035009037 Destination: 5cf47547-c8c0-4a67-89e6-92d035009037/af_1943_332_csv.zip
# 5cf47547-c8c0-4a67-89e6-92d035009037 zipfile found, skipping
# 08e463d3-043e-417d-9fcc-f512cd1827d3 Downloading: http://gstore.unm.edu/apps/rgis/datasets/5e780ee9-5bde-4e42-8911-a19132ca65ae/af_1943_394.derived.csv
# 08e463d3-043e-417d-9fcc-f512cd1827d3 Destination: 08e463d3-043e-417d-9fcc-f512cd1827d3/af_1943_394_csv.zip
# 08e463d3-043e-417d-9fcc-f512cd1827d3 zipfile found, skipping
# 2e7faf32-c634-4c65-9bac-13eb1f593ca3 Downloading: http://gstore.unm.edu/apps/rgis/datasets/309ea2eb-fac5-43f9-af5f-7e8eacf19745/af_1944_547.derived.csv
# 2e7faf32-c634-4c65-9bac-13eb1f593ca3 Destination: 2e7faf32-c634-4c65-9bac-13eb1f593ca3/af_1944_547_csv.zip
# 2e7faf32-c634-4c65-9bac-13eb1f593ca3 zipfile found, skipping
# 24c34bf0-35af-48f3-834f-37fb8603f7e6 Downloading: http://gstore.unm.edu/apps/rgis/datasets/3eabb530-454f-4036-b699-86510494d9fa/af_1944_649.derived.csv
# 24c34bf0-35af-48f3-834f-37fb8603f7e6 Destination: 24c34bf0-35af-48f3-834f-37fb8603f7e6/af_1944_649_csv.zip
# 24c34bf0-35af-48f3-834f-37fb8603f7e6 zipfile found, skipping
# 0e5aa333-b9f3-4713-8a00-3f407538730d Downloading: http://gstore.unm.edu/apps/rgis/datasets/6527aca7-2cf2-454d-8b26-94a0bdb7cb00/af_1944_661.derived.csv
# 0e5aa333-b9f3-4713-8a00-3f407538730d Destination: 0e5aa333-b9f3-4713-8a00-3f407538730d/af_1944_661_csv.zip
# 0e5aa333-b9f3-4713-8a00-3f407538730d zipfile found, skipping
# 79467697-0900-40ff-9ee3-da7c3127262b Downloading: http://gstore.unm.edu/apps/rgis/datasets/a4c47850-403c-4b0c-987e-368bcb989ebd/dce_1946.derived.csv
# 79467697-0900-40ff-9ee3-da7c3127262b Destination: 79467697-0900-40ff-9ee3-da7c3127262b/dce_1946_csv.zip
# 79467697-0900-40ff-9ee3-da7c3127262b zipfile found, skipping
# 4ffcc32d-ee5c-45a5-b7ee-35ebbffed319 Downloading: http://gstore.unm.edu/apps/rgis/datasets/661f9b78-a268-4b8f-b8d4-51e0643bc924/deo_eddy_1946.derived.csv
# 4ffcc32d-ee5c-45a5-b7ee-35ebbffed319 Destination: 4ffcc32d-ee5c-45a5-b7ee-35ebbffed319/deo_eddy_1946_csv.zip
# 4ffcc32d-ee5c-45a5-b7ee-35ebbffed319 zipfile found, skipping
# 7f246e15-9e34-4a59-9cdc-620f5666d648 Downloading: http://gstore.unm.edu/apps/rgis/datasets/f55102c7-9c36-4da8-97a2-5eceb989b9c1/ddo_1946.derived.csv
# 7f246e15-9e34-4a59-9cdc-620f5666d648 Destination: 7f246e15-9e34-4a59-9cdc-620f5666d648/ddo_1946_csv.zip
# 7f246e15-9e34-4a59-9cdc-620f5666d648 zipfile found, skipping
# 13f27a10-a890-4c2f-96ea-0bc151ac0742 Downloading: http://gstore.unm.edu/apps/rgis/datasets/9eed5d54-81e7-4711-8d09-765a8ae7fa87/ddq_1946.derived.csv
# 13f27a10-a890-4c2f-96ea-0bc151ac0742 Destination: 13f27a10-a890-4c2f-96ea-0bc151ac0742/ddq_1946_csv.zip
# 13f27a10-a890-4c2f-96ea-0bc151ac0742 zipfile found, skipping
# 152e8494-cd2e-4c12-800c-63e6ca02ae2b Downloading: http://gstore.unm.edu/apps/rgis/datasets/8e6e37f0-1078-4a2d-94a4-abc8aaf9a8bd/ddr_1946.derived.csv
# 152e8494-cd2e-4c12-800c-63e6ca02ae2b Destination: 152e8494-cd2e-4c12-800c-63e6ca02ae2b/ddr_1946_csv.zip
# 152e8494-cd2e-4c12-800c-63e6ca02ae2b zipfile found, skipping
# 8e99f002-96bc-4a37-b8e0-ed30d5d716dd Downloading: http://gstore.unm.edu/apps/rgis/datasets/3a5bd4d1-73eb-48b6-b6bb-c6c821b1f473/dfc_bernalillo_1947.derived.csv
# 8e99f002-96bc-4a37-b8e0-ed30d5d716dd Destination: 8e99f002-96bc-4a37-b8e0-ed30d5d716dd/dfc_bernalillo_1947_csv.zip
# 8e99f002-96bc-4a37-b8e0-ed30d5d716dd zipfile found, skipping
# a0c08ebd-d303-424e-b20d-52e70a54aeed Downloading: http://gstore.unm.edu/apps/rgis/datasets/3f35f2f0-3948-49dc-be0a-a30925bdb8a9/dey_donaana_1947.derived.csv
# a0c08ebd-d303-424e-b20d-52e70a54aeed Destination: a0c08ebd-d303-424e-b20d-52e70a54aeed/dey_donaana_1947_csv.zip
# a0c08ebd-d303-424e-b20d-52e70a54aeed zipfile found, skipping
# f9603edf-7a78-416c-ab10-ecd783bd166f Downloading: http://gstore.unm.edu/apps/rgis/datasets/a0b16118-a589-47fa-a3fc-4d15a2ffed8e/dfd_sandoval_1947.derived.csv
# f9603edf-7a78-416c-ab10-ecd783bd166f Destination: f9603edf-7a78-416c-ab10-ecd783bd166f/dfd_sandoval_1947_csv.zip
# f9603edf-7a78-416c-ab10-ecd783bd166f zipfile found, skipping
# 2afe87ee-7d10-4569-84b7-c8e525e81cf2 Downloading: http://gstore.unm.edu/apps/rgis/datasets/7be3a120-4395-4f33-8c3d-031eb81b67f9/dez_sierra_1947.derived.csv
# 2afe87ee-7d10-4569-84b7-c8e525e81cf2 Destination: 2afe87ee-7d10-4569-84b7-c8e525e81cf2/dez_sierra_1947_csv.zip
# 2afe87ee-7d10-4569-84b7-c8e525e81cf2 zipfile found, skipping
# 84bbf07b-c618-40a9-82ce-253d3e924a78 Downloading: http://gstore.unm.edu/apps/rgis/datasets/e8959d17-d44d-4952-a780-c59e4af32f51/dfa_socorro_1947.derived.csv
# 84bbf07b-c618-40a9-82ce-253d3e924a78 Destination: 84bbf07b-c618-40a9-82ce-253d3e924a78/dfa_socorro_1947_csv.zip
# 84bbf07b-c618-40a9-82ce-253d3e924a78 zipfile found, skipping
# 59c0100a-6ed3-4f21-a6a4-669659e6f911 Downloading: http://gstore.unm.edu/apps/rgis/datasets/5e230908-82e5-4c11-b224-5a53c756cb29/dfb_valencia_1947.derived.csv
# efb0cb94-5eca-4f00-b2a1-8b3dfdc5912c Downloading: https://data.nola.gov/api/views/hv7z-tzuv/rows.csv?accessType=DOWNLOAD
# efb0cb94-5eca-4f00-b2a1-8b3dfdc5912c Destination: efb0cb94-5eca-4f00-b2a1-8b3dfdc5912c/blocks_1990.csv
# 59c0100a-6ed3-4f21-a6a4-669659e6f911 Destination: 59c0100a-6ed3-4f21-a6a4-669659e6f911/dfb_valencia_1947_csv.zip
# 59c0100a-6ed3-4f21-a6a4-669659e6f911 zipfile found, skipping
# 8df7fc6a-967e-41f4-a8ea-d4b31f41da8b Downloading: http://gstore.unm.edu/apps/rgis/datasets/e982ac98-a05e-4a83-a384-e360677f82e8/dio_1950_az_nm.derived.csv
# 8df7fc6a-967e-41f4-a8ea-d4b31f41da8b Destination: 8df7fc6a-967e-41f4-a8ea-d4b31f41da8b/dio_1950_az_nm_csv.zip
# 8df7fc6a-967e-41f4-a8ea-d4b31f41da8b zipfile found, skipping
# dbaf1f20-2696-4f97-9973-f5ecf4128344 Downloading: http://gstore.unm.edu/apps/rgis/datasets/aa71804d-9e0a-4b6c-8771-c770c5b34264/dho_1949.derived.csv
# dbaf1f20-2696-4f97-9973-f5ecf4128344 Destination: dbaf1f20-2696-4f97-9973-f5ecf4128344/dho_1949_csv.zip
# dbaf1f20-2696-4f97-9973-f5ecf4128344 zipfile found, skipping
# eaf285b7-7f32-4096-8709-c7507bd57bbe Downloading: http://gstore.unm.edu/apps/rgis/datasets/f3b05ad1-a4c9-42b2-b341-9baade731c9e/cik_roosevelt_1949.derived.csv
# eaf285b7-7f32-4096-8709-c7507bd57bbe Destination: eaf285b7-7f32-4096-8709-c7507bd57bbe/cik_roosevelt_1949_csv.zip
# eaf285b7-7f32-4096-8709-c7507bd57bbe zipfile found, skipping
# 1844c754-c289-4af6-bbf6-4b746b77ffe1 Downloading: http://gstore.unm.edu/apps/rgis/datasets/18c0d25e-b448-4a5f-b570-2350ab2c8449/ciii_1950.derived.csv
# 1844c754-c289-4af6-bbf6-4b746b77ffe1 Destination: 1844c754-c289-4af6-bbf6-4b746b77ffe1/ciii_1950_csv.zip
# 1844c754-c289-4af6-bbf6-4b746b77ffe1 zipfile found, skipping
# 35c4837c-6ed5-4421-a16b-5ae333b2b6db Downloading: http://gstore.unm.edu/apps/rgis/datasets/b932ca2d-d821-4916-aaea-3d5510be417f/dho_1954.derived.csv
# 35c4837c-6ed5-4421-a16b-5ae333b2b6db Destination: 35c4837c-6ed5-4421-a16b-5ae333b2b6db/dho_1954_csv.zip
# 35c4837c-6ed5-4421-a16b-5ae333b2b6db zipfile found, skipping
# 5e4fdeac-1a6b-46e6-9221-a0a86834223e Downloading: http://gstore.unm.edu/apps/rgis/datasets/b623811b-8870-48c5-881c-1cb419fe6636/dho_1955.derived.csv
# 5e4fdeac-1a6b-46e6-9221-a0a86834223e Destination: 5e4fdeac-1a6b-46e6-9221-a0a86834223e/dho_1955_csv.zip
# 5e4fdeac-1a6b-46e6-9221-a0a86834223e zipfile found, skipping
# 0299c649-1603-4b0a-8388-84de4091250d Downloading: http://gstore.unm.edu/apps/rgis/datasets/dbe5ccda-7989-4123-8c08-3ff65baaecba/tlf11shp.derived.csv
# 0299c649-1603-4b0a-8388-84de4091250d Destination: 0299c649-1603-4b0a-8388-84de4091250d/tlf11shp_csv.zip
# 0299c649-1603-4b0a-8388-84de4091250d zipfile found, skipping
# 7919e7f0-5d79-4360-8cf7-7ebe1a563ed7 Downloading: http://gstore.unm.edu/apps/rgis/datasets/2eaef36c-cba0-49a8-83e9-56da0c9b7fe5/tlf10shp.derived.csv
# 7919e7f0-5d79-4360-8cf7-7ebe1a563ed7 Destination: 7919e7f0-5d79-4360-8cf7-7ebe1a563ed7/tlf10shp_csv.zip
# 7919e7f0-5d79-4360-8cf7-7ebe1a563ed7 zipfile found, skipping
# 21a9f43a-bc0b-444e-86d8-0080fc18d109 Downloading: https://data.nola.gov/api/views/9xra-d95k/rows.csv?accessType=DOWNLOAD
# 357ae2e9-916f-40e0-9c39-e235beeed24d Downloading: http://gstore.unm.edu/apps/rgis/datasets/8b986b09-7d02-4bef-87ac-d5a44ec28f97/ua99_d90_nmshp.derived.csv
# 3a79c812-3f8d-46b2-a915-567e91c784e2 Downloading: http://www.icpsr.umich.edu/icpsrweb/SAMHDA/series/64
# 2e462d97-9b25-43a8-b5f2-11dd3d7c8158 Downloading: https://data.cityofnewyork.us/api/views/kyad-zm4j/rows.csv?accessType=DOWNLOAD
# 771af6a9-3cba-4fdc-9092-887f1e296d00 Downloading: https://data.austintexas.gov/api/views/db24-fcaw/rows.csv?accessType=DOWNLOAD
# 88ed47e1-273b-402c-a1da-72558d1d288c Downloading: https://data.hawaii.gov/api/views/htqt-4ghe/rows.csv?accessType=DOWNLOAD
# 3a79c812-3f8d-46b2-a915-567e91c784e2 no content disposition found
# d4dcb8a7-6619-42ec-889d-a6bd708d19ae Downloading: http://www.icpsr.umich.edu/icpsrweb/SAMHDA/series/56
# 88ed47e1-273b-402c-a1da-72558d1d288c Destination: 88ed47e1-273b-402c-a1da-72558d1d288c/2.1d_VSAT_Recommend_Molokai_By_MMA.csv
# 771af6a9-3cba-4fdc-9092-887f1e296d00 Destination: 771af6a9-3cba-4fdc-9092-887f1e296d00/2-16_to_2-22-14_Austin_Animal_Center_Intakes.csv
# 4cc96d44-9109-4e97-823f-78f8e5fe3d83 Downloading: https://data.austintexas.gov/api/views/vs6n-chuq/rows.csv?accessType=DOWNLOAD
# d4dcb8a7-6619-42ec-889d-a6bd708d19ae no content disposition found
# c0fa42b8-9c85-4679-80ea-64cbae0c5a2e Downloading: http://www.icpsr.umich.edu/icpsrweb/SAMHDA/series/58
# 21a9f43a-bc0b-444e-86d8-0080fc18d109 Destination: 21a9f43a-bc0b-444e-86d8-0080fc18d109/blockgroups_1990.csv
# fced5825-ab8b-4713-9708-5b784e19667d Downloading: https://data.nola.gov/api/views/chdr-aebd/rows.csv?accessType=DOWNLOAD
# c0fa42b8-9c85-4679-80ea-64cbae0c5a2e no content disposition found
# 4cc96d44-9109-4e97-823f-78f8e5fe3d83 Destination: 4cc96d44-9109-4e97-823f-78f8e5fe3d83/2-16_to_2-22-14_Austin_Animal_Center_Outcomes.csv
# 357ae2e9-916f-40e0-9c39-e235beeed24d Destination: 357ae2e9-916f-40e0-9c39-e235beeed24d/ua99_d90_nmshp_csv.zip
# 357ae2e9-916f-40e0-9c39-e235beeed24d zipfile found, skipping
# 2e462d97-9b25-43a8-b5f2-11dd3d7c8158 Destination: 2e462d97-9b25-43a8-b5f2-11dd3d7c8158/1995_Street_Tree_Census.csv
# fced5825-ab8b-4713-9708-5b784e19667d Destination: fced5825-ab8b-4713-9708-5b784e19667d/tracts_1990.csv
# c087869b-705c-4fac-9441-3ed9a5d80b2a Downloading: https://data.austintexas.gov/api/views/ctnk-wvxm/rows.csv?accessType=DOWNLOAD
# ad5c1c78-2501-45c5-a6f3-f51997b59951 Downloading: https://data.wa.gov/api/views/dbre-5vfk/rows.csv?accessType=DOWNLOAD
# 32ffad14-c57a-4f0b-9ac1-47ad547fa1b8 Downloading: http://gstore.unm.edu/apps/rgis/datasets/6b217f0a-1f69-4dac-acef-417e4d0366a8/tgr2006se_bern_zcta300.derived.csv
# ad5c1c78-2501-45c5-a6f3-f51997b59951 Destination: ad5c1c78-2501-45c5-a6f3-f51997b59951/2_--_Government____By_Biennium.csv
# c087869b-705c-4fac-9441-3ed9a5d80b2a Destination: c087869b-705c-4fac-9441-3ed9a5d80b2a/2-9_to_2-15-14_Austin_Animal_Center_Outcomes.csv
# 32ffad14-c57a-4f0b-9ac1-47ad547fa1b8 Destination: 32ffad14-c57a-4f0b-9ac1-47ad547fa1b8/tgr2006se_bern_zcta300_csv.zip
# 32ffad14-c57a-4f0b-9ac1-47ad547fa1b8 zipfile found, skipping
# c05f8e8d-a5a6-46ed-9ce4-9467236987b1 Downloading: http://gstore.unm.edu/apps/rgis/datasets/bed15a20-f092-4c47-a9ff-813597b833e6/tgr2006se_catr_zcta300.derived.csv
# c05f8e8d-a5a6-46ed-9ce4-9467236987b1 Destination: c05f8e8d-a5a6-46ed-9ce4-9467236987b1/tgr2006se_catr_zcta300_csv.zip
# c05f8e8d-a5a6-46ed-9ce4-9467236987b1 zipfile found, skipping
# e66f2116-4626-48de-b715-c2b71ec8d223 Downloading: http://gstore.unm.edu/apps/rgis/datasets/be8b4f2b-6a04-41c2-b704-a4cd68981c34/tgr2006se_chav_zcta300.derived.csv
# e66f2116-4626-48de-b715-c2b71ec8d223 Destination: e66f2116-4626-48de-b715-c2b71ec8d223/tgr2006se_chav_zcta300_csv.zip
# e66f2116-4626-48de-b715-c2b71ec8d223 zipfile found, skipping
# c9e0d457-8304-40a6-8479-ee7d684c570e Downloading: http://gstore.unm.edu/apps/rgis/datasets/6a54902c-3b41-4a3d-b941-1b2370df8848/tgr2006se_cibo_zcta300.derived.csv
# c9e0d457-8304-40a6-8479-ee7d684c570e Destination: c9e0d457-8304-40a6-8479-ee7d684c570e/tgr2006se_cibo_zcta300_csv.zip
# c9e0d457-8304-40a6-8479-ee7d684c570e zipfile found, skipping
# 3a3cbad0-1e4e-4f0e-a024-9cad09341c7d Downloading: http://gstore.unm.edu/apps/rgis/datasets/ff038b79-afa6-4325-8adb-04212e0e1ba3/tgr2006se_colf_zcta300.derived.csv
# 3a3cbad0-1e4e-4f0e-a024-9cad09341c7d Destination: 3a3cbad0-1e4e-4f0e-a024-9cad09341c7d/tgr2006se_colf_zcta300_csv.zip
# 3a3cbad0-1e4e-4f0e-a024-9cad09341c7d zipfile found, skipping
# a2cd87d6-804e-45a3-9c92-4b15c8dfce35 Downloading: http://gstore.unm.edu/apps/rgis/datasets/8eb660cf-7468-4ae4-8875-ddc16bb220b4/tgr2006se_curr_zcta300.derived.csv
# a2cd87d6-804e-45a3-9c92-4b15c8dfce35 Destination: a2cd87d6-804e-45a3-9c92-4b15c8dfce35/tgr2006se_curr_zcta300_csv.zip
# a2cd87d6-804e-45a3-9c92-4b15c8dfce35 zipfile found, skipping
# 401553a8-993b-4f97-b5e6-eb396714e472 Downloading: http://gstore.unm.edu/apps/rgis/datasets/20f991ab-bb3b-4db3-89d5-edb779b4a434/tgr2006se_deba_zcta300.derived.csv
# 401553a8-993b-4f97-b5e6-eb396714e472 Destination: 401553a8-993b-4f97-b5e6-eb396714e472/tgr2006se_deba_zcta300_csv.zip
# 401553a8-993b-4f97-b5e6-eb396714e472 zipfile found, skipping
# 0ee3eaf4-fa42-4856-804b-33d98cc3f7a7 Downloading: http://gstore.unm.edu/apps/rgis/datasets/70c063db-bf30-4e8a-8a44-3c67f89c9f02/tgr2006se_dona_zcta300.derived.csv
# 0ee3eaf4-fa42-4856-804b-33d98cc3f7a7 Destination: 0ee3eaf4-fa42-4856-804b-33d98cc3f7a7/tgr2006se_dona_zcta300_csv.zip
# 0ee3eaf4-fa42-4856-804b-33d98cc3f7a7 zipfile found, skipping
# 406e008d-94b1-4fdc-91d5-923189f7b6f1 Downloading: http://gstore.unm.edu/apps/rgis/datasets/1530051b-a597-4dbe-bbbe-b41529bc48fd/tgr2006se_eddy_zcta300.derived.csv
# 406e008d-94b1-4fdc-91d5-923189f7b6f1 Destination: 406e008d-94b1-4fdc-91d5-923189f7b6f1/tgr2006se_eddy_zcta300_csv.zip
# 406e008d-94b1-4fdc-91d5-923189f7b6f1 zipfile found, skipping
# 8cff843e-8147-4b4b-96f2-d6ac18459eaa Downloading: http://gstore.unm.edu/apps/rgis/datasets/960cdb7f-9704-4c28-a116-14b8778d8c27/tgr2006se_gran_zcta300.derived.csv
# 8cff843e-8147-4b4b-96f2-d6ac18459eaa Destination: 8cff843e-8147-4b4b-96f2-d6ac18459eaa/tgr2006se_gran_zcta300_csv.zip
# 8cff843e-8147-4b4b-96f2-d6ac18459eaa zipfile found, skipping
# 0328a998-e54a-450f-bc01-37a09261d3cb Downloading: http://gstore.unm.edu/apps/rgis/datasets/2c5260dd-d7b1-46a2-913d-b3bcc3b20973/tgr2006se_guad_zcta300.derived.csv
# 0328a998-e54a-450f-bc01-37a09261d3cb Destination: 0328a998-e54a-450f-bc01-37a09261d3cb/tgr2006se_guad_zcta300_csv.zip
# 0328a998-e54a-450f-bc01-37a09261d3cb zipfile found, skipping
# bbadd5e2-9b0b-4797-b66e-5c1ba500f7fa Downloading: http://gstore.unm.edu/apps/rgis/datasets/0c5f1779-425c-49b5-a489-80b7147de39e/tgr2006se_hard_zcta300.derived.csv
# bbadd5e2-9b0b-4797-b66e-5c1ba500f7fa Destination: bbadd5e2-9b0b-4797-b66e-5c1ba500f7fa/tgr2006se_hard_zcta300_csv.zip
# bbadd5e2-9b0b-4797-b66e-5c1ba500f7fa zipfile found, skipping
# 9dcfb803-6ac1-4d29-8dc1-7db0aafc885f Downloading: http://gstore.unm.edu/apps/rgis/datasets/935dcb16-c7d2-4e02-8dc1-37233bb632f0/tgr2006se_hida_zcta300.derived.csv
# 9dcfb803-6ac1-4d29-8dc1-7db0aafc885f Destination: 9dcfb803-6ac1-4d29-8dc1-7db0aafc885f/tgr2006se_hida_zcta300_csv.zip
# 9dcfb803-6ac1-4d29-8dc1-7db0aafc885f zipfile found, skipping
# f1da6630-e31f-472f-9273-d83558af215f Downloading: http://gstore.unm.edu/apps/rgis/datasets/c86214da-dab1-4b1c-aef4-a199acb56998/tgr2006se_lea_zcta300.derived.csv
# f1da6630-e31f-472f-9273-d83558af215f Destination: f1da6630-e31f-472f-9273-d83558af215f/tgr2006se_lea_zcta300_csv.zip
# f1da6630-e31f-472f-9273-d83558af215f zipfile found, skipping
# d1fffed3-d343-4cfc-a133-6e592ce8f66c Downloading: http://gstore.unm.edu/apps/rgis/datasets/12da04f8-e95e-49e5-8b4c-6c7bad7a0f9f/tgr2006se_losa_zcta300.derived.csv
# d1fffed3-d343-4cfc-a133-6e592ce8f66c Destination: d1fffed3-d343-4cfc-a133-6e592ce8f66c/tgr2006se_losa_zcta300_csv.zip
# d1fffed3-d343-4cfc-a133-6e592ce8f66c zipfile found, skipping
# bd267629-8d6c-4839-aa86-4f80fed06094 Downloading: http://gstore.unm.edu/apps/rgis/datasets/d4c86837-707b-46a0-b81b-f430873d0038/tgr2006se_luna_zcta300.derived.csv
# bd267629-8d6c-4839-aa86-4f80fed06094 Destination: bd267629-8d6c-4839-aa86-4f80fed06094/tgr2006se_luna_zcta300_csv.zip
# bd267629-8d6c-4839-aa86-4f80fed06094 zipfile found, skipping
# b0895b67-b9d3-480d-8f64-0fa61ff80500 Downloading: http://gstore.unm.edu/apps/rgis/datasets/60f8abc4-be1b-44b5-8dfc-4ee98f4acf65/tgr2006se_mcki_zcta300.derived.csv
# b0895b67-b9d3-480d-8f64-0fa61ff80500 Destination: b0895b67-b9d3-480d-8f64-0fa61ff80500/tgr2006se_mcki_zcta300_csv.zip
# b0895b67-b9d3-480d-8f64-0fa61ff80500 zipfile found, skipping
# bfe767eb-922b-4629-a277-930e0c8449b9 Downloading: http://gstore.unm.edu/apps/rgis/datasets/aa7d93c0-7af0-4b85-83c1-52de34107342/tgr2006se_mora_zcta300.derived.csv
# bfe767eb-922b-4629-a277-930e0c8449b9 Destination: bfe767eb-922b-4629-a277-930e0c8449b9/tgr2006se_mora_zcta300_csv.zip
# bfe767eb-922b-4629-a277-930e0c8449b9 zipfile found, skipping
# 7bde2718-6e4c-4f9b-8b8f-0824c61d7af0 Downloading: http://gstore.unm.edu/apps/rgis/datasets/7da661ac-e221-4f4d-b3f3-4ac44e509393/tgr2006se_oter_zcta300.derived.csv
# 7bde2718-6e4c-4f9b-8b8f-0824c61d7af0 Destination: 7bde2718-6e4c-4f9b-8b8f-0824c61d7af0/tgr2006se_oter_zcta300_csv.zip
# 7bde2718-6e4c-4f9b-8b8f-0824c61d7af0 zipfile found, skipping
# 03db3ff1-ea20-4c70-b657-4acf6226d691 Downloading: http://gstore.unm.edu/apps/rgis/datasets/cd8736f7-4796-4cbe-a91e-b5cee6c64ab9/tgr2006se_quay_zcta300.derived.csv
# 03db3ff1-ea20-4c70-b657-4acf6226d691 Destination: 03db3ff1-ea20-4c70-b657-4acf6226d691/tgr2006se_quay_zcta300_csv.zip
# 03db3ff1-ea20-4c70-b657-4acf6226d691 zipfile found, skipping
# f3b66055-00f0-4b0c-b035-c249b848089f Downloading: http://gstore.unm.edu/apps/rgis/datasets/01440718-f689-4aad-99ab-09a8814d72e0/tgr2006se_rioa_zcta300.derived.csv
# f3b66055-00f0-4b0c-b035-c249b848089f Destination: f3b66055-00f0-4b0c-b035-c249b848089f/tgr2006se_rioa_zcta300_csv.zip
# f3b66055-00f0-4b0c-b035-c249b848089f zipfile found, skipping
# 6977b673-8e0a-413a-8bf5-7403d41fb76a Downloading: http://gstore.unm.edu/apps/rgis/datasets/bff48c0e-2ff9-4406-8c70-725250356651/tgr2006se_roos_zcta300.derived.csv
# 6977b673-8e0a-413a-8bf5-7403d41fb76a Destination: 6977b673-8e0a-413a-8bf5-7403d41fb76a/tgr2006se_roos_zcta300_csv.zip
# 6977b673-8e0a-413a-8bf5-7403d41fb76a zipfile found, skipping
# 5f39053f-56a5-4692-8ed3-a2bdc8c979c6 Downloading: http://gstore.unm.edu/apps/rgis/datasets/44d6c2ec-5b19-4a11-8830-993362af2498/tgr2006se_sanj_zcta300.derived.csv
# 5f39053f-56a5-4692-8ed3-a2bdc8c979c6 Destination: 5f39053f-56a5-4692-8ed3-a2bdc8c979c6/tgr2006se_sanj_zcta300_csv.zip
# 5f39053f-56a5-4692-8ed3-a2bdc8c979c6 zipfile found, skipping
# 74da46da-b607-41d2-89e7-c421bb982509 Downloading: http://gstore.unm.edu/apps/rgis/datasets/60b89221-4f39-4e28-b544-c93fd4d09033/tgr2006se_sanm_zcta300.derived.csv
# 74da46da-b607-41d2-89e7-c421bb982509 Destination: 74da46da-b607-41d2-89e7-c421bb982509/tgr2006se_sanm_zcta300_csv.zip
# 74da46da-b607-41d2-89e7-c421bb982509 zipfile found, skipping
# 6000155f-c397-4475-9657-3b7a31f870e1 Downloading: http://gstore.unm.edu/apps/rgis/datasets/24d29701-d143-4015-98f8-b99f708ae75d/tgr2006se_sand_zcta300.derived.csv
# 6000155f-c397-4475-9657-3b7a31f870e1 Destination: 6000155f-c397-4475-9657-3b7a31f870e1/tgr2006se_sand_zcta300_csv.zip
# 6000155f-c397-4475-9657-3b7a31f870e1 zipfile found, skipping
# 4d1620e7-2d3f-4d96-82ab-1082f229e0d3 Downloading: http://gstore.unm.edu/apps/rgis/datasets/236d17aa-1e36-4df7-a02a-2ff03e72f5db/tgr2006se_sant_zcta300.derived.csv
# 4d1620e7-2d3f-4d96-82ab-1082f229e0d3 Destination: 4d1620e7-2d3f-4d96-82ab-1082f229e0d3/tgr2006se_sant_zcta300_csv.zip
# 4d1620e7-2d3f-4d96-82ab-1082f229e0d3 zipfile found, skipping
# 56f85209-c157-42ad-9b25-be7ef8225ff1 Downloading: http://gstore.unm.edu/apps/rgis/datasets/0439989b-af24-4e54-9f13-d3a2db476868/tgr2006se_sier_zcta300.derived.csv
# 56f85209-c157-42ad-9b25-be7ef8225ff1 Destination: 56f85209-c157-42ad-9b25-be7ef8225ff1/tgr2006se_sier_zcta300_csv.zip
# 56f85209-c157-42ad-9b25-be7ef8225ff1 zipfile found, skipping
# cc9c0c3d-5e0d-49fc-b187-b06a928be5a5 Downloading: http://gstore.unm.edu/apps/rgis/datasets/8746a2fc-c3b0-4d98-8ef8-3770d7f254df/tgr2006se_soco_zcta300.derived.csv
# cc9c0c3d-5e0d-49fc-b187-b06a928be5a5 Destination: cc9c0c3d-5e0d-49fc-b187-b06a928be5a5/tgr2006se_soco_zcta300_csv.zip
# cc9c0c3d-5e0d-49fc-b187-b06a928be5a5 zipfile found, skipping
